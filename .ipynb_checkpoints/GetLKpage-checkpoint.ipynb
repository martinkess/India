# %%
from pyquery import PyQuery as pq
import urllib2
import requests
import pandas as pd
import re
import time
import numpy as np
import json

# %% [markdown]
# Define URLs:

# %%
ls_2014 = "http://myneta.info/ls2014/index.php?action=show_winners&sort=default"
ls_2009 = "http://myneta.info/ls2009/index.php?action=show_winners&sort=default"
ls_2004 = "http://myneta.info/loksabha2004/index.php?action=show_winners&sort=default"

# %% [markdown]
# Define function to download and create dataframe

# %%
def process_winner_link(link, year):
    
    html = requests.get(link)
    doc = pq(html.content)
    trs = doc('table').eq(2).children('tr')

    datalist=[]

    for tr in trs:
        winner_dict = {'year':year}
        for i,td in enumerate(tr.findall('td')):
            if i == 0:
                winner_dict['idnum'] = td.text
            if i == 1:
                winner_dict['name'] = td.findall('a')[1].text
            if i == 2:
                winner_dict['constituency'] = td.text
            if i == 3:
                winner_dict['party'] = td.text
            if i == 4:
                winner_dict['crim_cases'] = td.text
                if td.text == None:
                    winner_dict['crim_cases'] = td.find('span').text
            if i == 5:
                winner_dict['education'] = td.text
            if i == 6:
                winner_dict['assets'] =  td.text.replace(',','').replace('Rs','').lstrip()
            if i == 7:
                winner_dict['liabilities'] =  td.text.replace(',','').replace('Rs','').lstrip()

        datalist.append(winner_dict)

    return pd.DataFrame(datalist)

# %%
df_winner_14 = process_winner_link(ls_2014, 2014)
df_winner_09 = process_winner_link(ls_2009, 2009)
df_winner_04 = process_winner_link(ls_2004, 2004)
df_winner_master = pd.concat([df_14,df_09,df_04])
df_winner_master.to_csv('loksabha_win.csv')

# %%
base_candidate = "http://myneta.info/ls"
suffix_candidate = "/index.php?action=show_candidates&constituency_id="

# %%
def get_constituents(year, thelink):
    html = requests.get(thelink)
    doc = pq(html.content)
    trs = doc('table').eq(2).find('tr')
    datalist=[]
    print len(trs)
    for tr in trs:
        new_state = pq(tr)('th').text()
        if new_state != "":
            curr_state = new_state 
            #print "state: %s" % curr_state
        else:
            districts = pq(tr)('td')
            if districts != "":
                for x in districts:
                    dist_name = pq(x)('a').text()
                    if dist_name != "":
                        district_dict = {'year':year, 'state':curr_state}
                        district_dict['district'] = dist_name
                        district_dict['thelink'] = pq(x)('a').attr.href
                        datalist.append(district_dict)

    return pd.DataFrame(datalist)

# %%
thelink = 'http://myneta.info/ls2014/'
mynetasite = 'http://myneta.info/'
districts = get_constituents(2014, thelink)
# Out:
# 226

# %%
#for link in districts.thelink :
    
masterlink = 'http://myneta.info/ls2014/index.php?action=show_candidates&constituency_id=23'
thepage = requests.get(masterlink)
doc = pq(thepage.content)
print doc
#print len(doc('.divTableWithFloatingHeader'))
# Out:
# <html>
# 				<head>
# 				   <title>List of Candidates in ARUNACHAL WEST:ARUNACHAL PRADESH</title>
# 				   <meta name="description" content="It provides criminal and financial background information on candidates, MPs and MLAs contesting in elections.It also has information on income and expenditure of political parties."/>
#     				<meta charset="utf-8"/>
#     				<meta http-equiv="x-ua-compatible" content="ie=edge"/>
#     				<meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1"/>
#     				<meta name="author" content="ADR"/>
#     				<link rel="stylesheet" href="/lib/css/text.css"/>
#     				<link rel="stylesheet" href="/lib/css/main.css"/>
#     				<link href="http://fonts.googleapis.com/css?family=Rokkitt:400,700" rel="stylesheet" type="text/css"/>
#     				<link href="http://fonts.googleapis.com/css?family=Droid+Sans:400,700" rel="stylesheet" type="text/css"/>
# 					<script type="text/javascript">
# 						function confirmation()
# 						{
# 							if (document.form1.discrepancy.value.length&lt;= 49)
# 							{
# 								alert('Please enter at least 50 characters in discrepancy!');
# 								return false;
# 							}
# 							return true;
# 						}
# 					</script>
#     				<script src="https://ajax.googleapis.com/ajax/libs/jquery/1.7.2/jquery.min.js"/>
#     				<script src="/lib/js/adapt-config.js"/>
#     				<script src="/lib/js/adapt.min.js"/>
# 					<script src="/lib/js/fix-table-header.js"/>
#     				<script src="/lib/js/app.js"/>
# 					<!-- Put the following javascript before the closing </head> tag. -->
# 					<script>
#   					(function() {
#    						var cx = '014214505007285591097:vf77t8iuwrc';
#     					var gcse = document.createElement('script'); gcse.type = 'text/javascript'; gcse.async = true;
#     					gcse.src = (document.location.protocol == 'https:' ? 'https:' : 'http:') +'//www.google.com/cse/cse.js?cx=' + cx;
#     					var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(gcse, s);
#   					})();
# 					</script>
#
# 				<script type="text/javascript">
#   				var _gaq = _gaq || [];
#   				_gaq.push(['_setAccount', 'UA-26901527-2']);
#   				_gaq.push(['_setDomainName', 'myneta.info']);
#   				_gaq.push(['_trackPageview']);
#
#   				(function() {
#    				 var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     				ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     				var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   				})();
# 				</script>
#
# 				</head>
# 				<body>
# 					<!--<div align=right><a href="https://play.google.com/store/apps/details?id=com.webrosoft.myneta1"><img src="/lib/img/android-logo-small.png" />Myneta Android App </a>	</div>-->
# 					<!--Logos-->
# 					<div class="container_12">
# 						<div class="grid_3 logo">
# 					        <a href="/"><img src="/lib/img/myneta-logo.jpg" title="MyNeta Logo" alt="Myneta Logo"/></a>
# 					    </div>
# 						<div class="grid_6" style="text-align:center;vertical-align: bottom;">
# 							<br/><br/>
# 	    					<form action="/search_myneta.php" method="get" align="center" valgin="bottom">
#        							<input type="text" name="q" placeholder="Neta/Constituency Name" size="20"/>
#         						&#8194;<input type="submit" value="Search"/>
#         						&#8194;<a href="http://myneta.info/advance_search.php" style="text-decoration:none;">Advance search</a>
#     						</form>
# 						</div>
#    						<div class="grid_3 logo">
# 				        	<a href="http://adrindia.org" target="_blank"><img src="/lib/img/logo-adr.png" title="ADR Logo" id="adr-logo"/></a>
# 				    	</div>
# 					</div>
#
# 					<!--Menus -->
# 					<div class="menu-bg">
# 					    <div class="container_12">
# 					        <div class="grid_12">
# 					            <ul class="main-menu">
# 					                <li><a href="/">Home</a></li>
# 					                <li><a href="http://adrindia.org/about-adr/who-we-are" target="_blank" title="About ADR">About ADR</a>  </li>
# 							<li><a href="http://myneta.info/#ls" title="Election Watch">Lok Sabha</a></li>
# 					               	<li><a href="http://myneta.info/#rs" title="Research &amp; Reports">Rajya Sabha</a></li>
# 							<li><a href="http://myneta.info/party" title="Political Parties">Political Parties <img width="30" height="20" border="0" src="http://myneta.info/new.gif"/></a></li>
# 						        <li><a href="http://adrindia.org/about-adr/state-coordinators" target="_blank" title="Partners">Partners</a></li>
# 					                <li><a href="http://adrindia.org/contact-us" target="_blank" title="Contact Us">Contact Us</a></li>
# 							<li><a href="http://adrindia.org/donate" target="_blank" title="Donate">Donate</a></li>
# 							<li><a href="http://translate.google.co.in/translate?prev=hp&amp;hl=en&amp;js=y&amp;u=myneta.info&amp;sl=en&amp;tl=hi&amp;history_state0=" style="text-decoration: none">&#2405;&#2350;&#2366;&#2351; &#2344;&#2375;&#2340;&#2366; &#2361;&#2367;&#2306;&#2342;&#2368; &#2350;&#2375;&#2405;</a></li>
# 						          </ul>
# 					        </div>
# 					    </div>
# 					</div>
# 					<div class="banner-bg">
# 						<div class="container_12">
# 							<div class="grid_12">
#
# 								<li><img src="/lib/img/banner/banner-3.png"/></li>
# 							</div>
# 						</div>
# 					</div>
#
# 					<!--Main Content-->
# 					<div id="main">
# 						<div class="container_12">
# 							<div class="items"><a href="http://myneta.info/">Home</a>&#8594;<a href="http://myneta.info/ls2014/">Loksabha 2014</a>&#8594;<a href="http://myneta.info/ls2014/index.php?action=show_constituencies&amp;state_id=2">ARUNACHAL PRADESH</a>&#8594;<b>ARUNACHAL WEST</b><hr/></div>
# 							<div class="grid_9">
# 								<h2 class="title first">Loksabha 2014
# 									<a name="summary"/><h3 class="title blue first">Election Summary</h3><span class="grid_9"><span class="grid_4">
# 	<table style="padding:2px;border:0;">
# 	<tr><th valign="center">HIGHLIGHTS OF CANDIDATES</th></tr>
# 	<tr><td><b>Total number of constituencies analyzed (All Phases)=545</b></td></tr>
# 	<tr><td><a href="index.php?action=summary&amp;subAction=candidates_analyzed&amp;sort=candidate#summary">Total candidates analyzed by NEW = <b>8204</b></a></td></tr>
# 	<tr><td><a href="index.php?action=summary&amp;subAction=crime&amp;sort=candidate#summary">Candidates with declared criminal cases = <b>1404 (17%)</b></a></td></tr>
# 	<tr><td><a href="index.php?action=summary&amp;subAction=serious_crime&amp;sort=candidate#summary">Candidates with declared serious criminal cases = <b>908 (11%)</b></a></td></tr>
# 	<tr><td><a href="index.php?action=summary&amp;subAction=crorepati&amp;sort=candidate#summary">Crorepati candidates = <b>2217 (27%)</b></a></td></tr>
# 	<tr><td><a href="index.php?action=summary&amp;subAction=education&amp;sort=candidate#summary">Candidates who are graduate or above = <b>4025 (49%)</b></a></td></tr>
# 	<tr><td><a href="index.php?action=summary&amp;subAction=without_pan&amp;sort=candidate#summary">Candidates who have not declared PAN = <b>2341 (29%)</b></a></td></tr>
# 	<tr><td><a href="index.php?action=summary&amp;subAction=women_candidate&amp;sort=candidate#summary">Total women candidates  = <b>640 (8%)</b></a></td></tr>
# 	<tr><td><a href="index.php?action=summary&amp;subAction=filed_itr&amp;sort=candidate#summary">Total candidates who have filed ITR = <b>3752 (46%)</b></a></td></tr>
# 	</table></span><span class="grid_4">	<table style="padding:2px;border:0;">
# 	<tr><th>HIGHLIGHTS OF WINNERS</th></tr>
# 	<tr><td>&#160;</td></tr>
# 	<tr><td><a href="index.php?action=summary&amp;subAction=winner_analyzed&amp;sort=candidate#summary">Total winners analyzed by NEW = <b>542</b></a></td></tr>
# 	<tr><td><a href="index.php?action=summary&amp;subAction=winner_crime&amp;sort=candidate#summary">Winners with declared criminal cases = <b>185 (34%)</b></a></td></tr>
# 	<tr><td><a href="index.php?action=summary&amp;subAction=winner_serious_crime&amp;sort=candidate#summary">Winners with declared serious criminal cases = <b>119 (22%)</b></a></td></tr>
# 	<tr><td><a href="index.php?action=summary&amp;subAction=winner_crorepati&amp;sort=candidate#summary">Crorepati winners = <b>443 (82%)</b></a></td></tr>
# 	<tr><td><a href="index.php?action=summary&amp;subAction=winner_education&amp;sort=candidate#summary">Winners who are graduate or above = <b>406 (75%)</b></a></td></tr>
# 	<tr><td><a href="index.php?action=summary&amp;subAction=winner_without_pan&amp;sort=candidate#summary">Winners  who have not declared PAN = <b>7 (1%)</b></a></td></tr>
# 	<tr><td><a href="index.php?action=summary&amp;subAction=winner_women&amp;sort=candidate#summary">Total women winners  = <b>62 (11%)</b></a></td></tr>
# 	<tr><td><a href="index.php?action=summary&amp;subAction=winner_filed_itr&amp;sort=candidate#summary">Total winners who have filed ITR = <b>498 (92%)</b></a></td></tr>
# 	</table></span></span><div class="clearfix"/><div class="title"><h3>List of Candidates - ARUNACHAL WEST:ARUNACHAL PRADESH (<a href="comparisonchart.php?constituency_id=23" target="_blank">Comparison Chart of Party Candidates</a>)</h3> </div><span style="font-size:120%;color:red;background-color:yellow"/>  <br/></h2><table width="100%" id="table1">
#                 <tr>
#                 <th>Candidate</th><th>Party</th>
#                 <th align="center">Criminal Cases</th>
#                 <th>Education</th>
#                 <th>Age</th>
#                 <th align="right">Total Assets</th>
#                 <th align="right">Liabilities</th>
#                 </tr>
#
#                     <tr style="font-family:verdana;font-size:80%;" onmouseover="this.style.backgroundColor='skyblue'" onmouseout="this.style.backgroundColor='#ffffff'">
#                     <td><a href="candidate.php?candidate_id=246">Kiren Rijiju</a><b>&amp;nbsp&amp;nbsp<font color="green" size="1"> Winner </font></b></td>
#                     <td>BJP</td>
#                     <td align="center" style="">0</td>
#                     <td>Graduate Professional</td><td>42</td>
#                     <td align="right">Rs&#160;1,25,39,868<br/><span style="color:black;font-size:70%;text-decoration:none;white-space:nowrap"> ~ 1&#160;Crore+</span></td>
#                     <td align="right">Rs&#160;4,75,000<br/><span style="color:black;font-size:70%;text-decoration:none;white-space:nowrap"> ~ 4&#160;Lacs+</span></td>
#                     </tr>
#
#                     <tr style="font-family:verdana;font-size:80%;" onmouseover="this.style.backgroundColor='skyblue'" onmouseout="this.style.backgroundColor='#ffffff'">
#                     <td><a href="candidate.php?candidate_id=874">Gicho Kabak</a><b/></td>
#                     <td>NCP</td>
#                     <td align="center" style="">0</td>
#                     <td>10th Pass</td><td>49</td>
#                     <td align="right">Rs&#160;4,00,000<br/><span style="color:black;font-size:70%;text-decoration:none;white-space:nowrap"> ~ 4&#160;Lacs+</span></td>
#                     <td align="right">Rs&#160;0<br/><span style="color:black;font-size:70%;text-decoration:none;white-space:nowrap"> ~ </span></td>
#                     </tr>
#                     <tr style="font-family:verdana;font-size:80%;" onmouseover="this.style.backgroundColor='skyblue'" onmouseout="this.style.backgroundColor='#ffffff'">
#                     <td><a href="candidate.php?candidate_id=875">Gumjum Haider</a><b/></td>
#                     <td>AITC</td>
#                     <td align="center" style="">0</td>
#                     <td>Graduate</td><td>36</td>
#                     <td align="right">Rs&#160;88,08,016<br/><span style="color:black;font-size:70%;text-decoration:none;white-space:nowrap"> ~ 88&#160;Lacs+</span></td>
#                     <td align="right">Rs&#160;0<br/><span style="color:black;font-size:70%;text-decoration:none;white-space:nowrap"> ~ </span></td>
#                     </tr>
#                     <tr style="font-family:verdana;font-size:80%;" onmouseover="this.style.backgroundColor='skyblue'" onmouseout="this.style.backgroundColor='#ffffff'">
#                     <td><a href="candidate.php?candidate_id=951">Habung Payeng</a><b/></td>
#                     <td>AAP</td>
#                     <td align="center" style="">0</td>
#                     <td>Post Graduate</td><td>56</td>
#                     <td align="right">Rs&#160;1,45,87,055<br/><span style="color:black;font-size:70%;text-decoration:none;white-space:nowrap"> ~ 1&#160;Crore+</span></td>
#                     <td align="right">Rs&#160;0<br/><span style="color:black;font-size:70%;text-decoration:none;white-space:nowrap"> ~ </span></td>
#                     </tr>
#                     <tr style="font-family:verdana;font-size:80%;" onmouseover="this.style.backgroundColor='skyblue'" onmouseout="this.style.backgroundColor='#ffffff'">
#                     <td><a href="candidate.php?candidate_id=472">Jalley Sonam</a><b/></td>
#                     <td>PPA</td>
#                     <td align="center" style="">0</td>
#                     <td>10th Pass</td><td>33</td>
#                     <td align="right">Rs&#160;46,80,000<br/><span style="color:black;font-size:70%;text-decoration:none;white-space:nowrap"> ~ 46&#160;Lacs+</span></td>
#                     <td align="right">Rs&#160;0<br/><span style="color:black;font-size:70%;text-decoration:none;white-space:nowrap"> ~ </span></td>
#                     </tr>
#                     <tr style="font-family:verdana;font-size:80%;" onmouseover="this.style.backgroundColor='skyblue'" onmouseout="this.style.backgroundColor='#ffffff'">
#                     <td><a href="candidate.php?candidate_id=953">Subu Kechi</a><b/></td>
#                     <td>IND</td>
#                     <td align="center" style=""><span style="color:red;font-weight:bold;font-size:150%"> 1 </span></td>
#                     <td>Graduate Professional</td><td>40</td>
#                     <td align="right">Rs&#160;7,85,000<br/><span style="color:black;font-size:70%;text-decoration:none;white-space:nowrap"> ~ 7&#160;Lacs+</span></td>
#                     <td align="right">Rs&#160;0<br/><span style="color:black;font-size:70%;text-decoration:none;white-space:nowrap"> ~ </span></td>
#                     </tr>
#                     <tr style="font-family:verdana;font-size:80%;" onmouseover="this.style.backgroundColor='skyblue'" onmouseout="this.style.backgroundColor='#ffffff'">
#                     <td><a href="candidate.php?candidate_id=952">Taba Taku</a><b/></td>
#                     <td>Lok Bharati</td>
#                     <td align="center" style="">0</td>
#                     <td>Graduate</td><td>34</td>
#                     <td align="right">Rs&#160;62,00,000<br/><span style="color:black;font-size:70%;text-decoration:none;white-space:nowrap"> ~ 62&#160;Lacs+</span></td>
#                     <td align="right">Rs&#160;0<br/><span style="color:black;font-size:70%;text-decoration:none;white-space:nowrap"> ~ </span></td>
#                     </tr>
#                     <tr style="font-family:verdana;font-size:80%;" onmouseover="this.style.backgroundColor='skyblue'" onmouseout="this.style.backgroundColor='#ffffff'">
#                     <td><a href="candidate.php?candidate_id=405">Takam Sanjoy</a><b/></td>
#                     <td>INC</td>
#                     <td align="center" style="">0</td>
#                     <td>Graduate</td><td>47</td>
#                     <td align="right">Rs&#160;10,59,15,042<br/><span style="color:black;font-size:70%;text-decoration:none;white-space:nowrap"> ~ 10&#160;Crore+</span></td>
#                     <td align="right">Rs&#160;0<br/><span style="color:black;font-size:70%;text-decoration:none;white-space:nowrap"> ~ </span></td>
#                     </tr>
#                 </table>
# 							</div>
# 							<div class="grid_3" xmlns="http://www.w3.org/1999/html">
# 							 <!--	<h3 class="title blue first">ADR-Facebook Initiative</h3>
# 								<a href='http://adrindia.org/content/adr-and-facebook-join-hands-provide-information-%E2%80%98know-your-neta%E2%80%99-mobiles-free-dial-32535' target=_blank><img src="/lib/img/campaign.png"></a><hr> -->
#     						    <h3 class="title">Find us on facebook</h3>
# 								<div class="fb-plugin-container">
#         							<div class="fb-like-box" data-href="http://www.facebook.com/myneta.info" data-border-color="#ffffff" data-width="250" data-show-faces="true" data-stream="false" data-header="false" show-border="false"/>
#     							</div>
# 								<h3 class="title">Myneta Android App</h3>
# 								<a href="https://play.google.com/store/apps/details?id=com.webrosoft.myneta1" target="_blank"><img src="/lib/img/Myneta.app.png"/></a>
#  							    <h3 class="title">HelpLine &amp; SMS</h3>
# 							    <p>You can get complete details of your Neta by calling us at 1800-110-440 or sending SMS at 9246556070. For more details <a href="http://adrindia.org/media/helpline-sms" target="_blank">click here</a>.</p>
# 								<h3 class="title purple">Connect with us</h3>
# 								<div id="fb-root"/>
#    	 							<script>(function (d, s, id) {
#         							var js, fjs = d.getElementsByTagName(s)[0];
#         							if (d.getElementById(id)) return;
#         							js = d.createElement(s);
#         							js.id = id;
#         							js.src = "//connect.facebook.net/en_GB/all.js#xfbml=1";
#         							fjs.parentNode.insertBefore(js, fjs);
#     								}(document, 'script', 'facebook-jssdk'));</script>
# 							    <div class="social-icon">
#         							<a target="_blank" title="Connect with us on Facebook" href="http://facebook.com/myneta.info"><img src="/lib/img/facebook.png" alt="Facebook Page"/> </a>
#         							<a target="_blank" title="Connect with us on Twitter" href="http://twitter.com/adrspeaks"><img src="/lib/img/twitter.png" alt="Twitter"/></a>
#         							<a target="_blank" title="Be a part of our Google Group" href="https://groups.google.com/group/national-election-watch?hl=en&amp;pli=1"><img src="/lib/img/google.png" alt="Google newsletter"/></a>
# 							        <div class="fb-like" data-href="http://facebook.com/myneta.info" data-send="false" data-layout="button_count" data-show-faces="false"/>
# 							    </div>
# 							    <div class="newsletter-form">For news alert,enter your email id
#         							<form action="http://groups.google.com/group/national-election-watch/boxsubscribe" target="_blank">
#             							<input type="text" id="tb-email-gg" name="email" value="" placeholder="email-id to subscribe"/>
#             							<input type="submit" value="Join"/>
#         							</form>
#    								</div>
# 							</div>
# 					    </div>
# 					</div>
#
# 					<!--Footer Area-->
# 					<div class="footer">
# 						<div class="container_12">
# 					    	<div class="grid_12">
# 					            <p> <b>Disclaimer: </b> The primary source for the data used for these reports is the sworn affidavits provided by the candidates themselves. Sheer volume of data that has to be read from the affidavits that are often poorly scanned and the lightening speed at which these reports have to be brought out makes it quite difficult to ensure accuracy of every bit of data. In case of any discrepancy in our reports vis a vis the original affidavit of any candidate, the original affidavit should be considered accurate. If you notice any discrepancies between affidavit and our report kindly let us know and we will fix them on our end as soon as possible.
# 					           </p>
# 					        </div>
# 						</div>
# 					</div>
# 					<p align="center">Technology Powered by <a href="http://www.webrosoft.com/" target="_blank">Webrosoft</a></p>
# 				</body>
# 			</html>
